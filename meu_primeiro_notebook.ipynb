# %% [markdown]
# <a href="https://colab.research.google.com/github/viniciushodos/Projetos-da-disciplina-de-Cincia-de-Dados-e-IA/blob/main/meu_primeiro_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
soma = int(input('digite um numero '))
soma2 = int(input('digite outro numero'))
print(soma + soma2)
# Out:
# digite um numero 6
# digite outro numero5
# 11

# %%
1 + 1
# Out:
# 2
